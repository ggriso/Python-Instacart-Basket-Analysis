# %% [markdown]
# # 4.8 Grouping data & aggregating variables

# %% [markdown]
# Table of Contents
#
# #### 1. Import the data sets into Jupyter
# #### 2. Create a subset of the dataframe
# #### 3. Check the shape of the newly created dataframe
# #### 4. Grouping data
# #### 5. Create a column to generate the maximum orders for each user
# #### 6. Create a loyalty flag using loc
# #### 7. Find the aggregated mean of the 'order_number' column grouped by 'department_id'
# #### 8. Look at spending habits of loyalty groups
# #### 9. Determine order frequency of each user
# #### 10. Quality check for the 'prices' column
# #### 11. Export updated dataframe

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ### 1. Import the data sets into Jupyter

# %%
# Tell Python to remember a main folder path
path = r'/Users/giadairene/Documents/CareerFoundry Data Analytics/Data Analytics Immersion/Achievement 4/Instacart Basket Analysis'

# %%
# Import dataset ords_prods_merge_derived.pkl
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merge_derived.pkl'))

# %% [markdown]
# ### 2. Create a subset of the dataframe

# %%
# Create a subset of the dataframe
df = ords_prods_merge[:1000000]

# %% [markdown]
# ### 3. Check the shape of the newly created dataframe

# %%
df.head(10)
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
# 5           1  Chocolate Sandwich Cookies        61             19     5.8
# 6           1  Chocolate Sandwich Cookies        61             19     5.8
# 7           1  Chocolate Sandwich Cookies        61             19     5.8
# 8           1  Chocolate Sandwich Cookies        61             19     5.8
# 9           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   3139998      138            28                   6                 11
# 1   1977647      138            30                   6                 17
# 2    389851      709             2                   0                 21
# 3    652770      764             1                   3                 13
# 4   1813452      764             3                   4                 17
# 5   1701441      777            16                   1                  7
# 6   1871483      825             3                   2                 14
# 7   1290456      910            12                   3                 10
# 8    369558     1052            10                   1                 20
# 9    589712     1052            15                   1                 12
#
#    days_since_prior_order  first_order  add_to_cart_order  reordered _merge  \
# 0                     3.0        False                  5          0   both
# 1                    20.0        False                  1          1   both
# 2                     6.0        False                 20          0   both
# 3                     NaN         True                 10          0   both
# 4                     9.0        False                 11          1   both
# 5                    26.0        False                  7          0   both
# 6                    30.0        False                  2          0   both
# 7                    30.0        False                  1          0   both
# 8                    19.0        False                  1          0   both
# 9                    15.0        False                  2          1   both
#
#      price_range_loc     busiest_day busiest_period_of_day
# 0  Mid-range product  Regularly busy           Most orders
# 1  Mid-range product  Regularly busy        Average orders
# 2  Mid-range product    Busiest days        Average orders
# 3  Mid-range product      Least busy           Most orders
# 4  Mid-range product      Least busy        Average orders
# 5  Mid-range product    Busiest days        Average orders
# 6  Mid-range product  Regularly busy           Most orders
# 7  Mid-range product      Least busy           Most orders
# 8  Mid-range product    Busiest days        Average orders
# 9  Mid-range product    Busiest days           Most orders

# %%
df.shape
# Out:
# (1000000, 18)

# %% [markdown]
# ### 4. Grouping data

# %%
# Split the data into groups based on 'department_id'

df = df.groupby('department_id')

# %%
# Check the output 

df.head(10)
# Out:
#         product_id                product_name  aisle_id  department_id  \
# 0                1  Chocolate Sandwich Cookies        61             19
# 1                1  Chocolate Sandwich Cookies        61             19
# 2                1  Chocolate Sandwich Cookies        61             19
# 3                1  Chocolate Sandwich Cookies        61             19
# 4                1  Chocolate Sandwich Cookies        61             19
# ...            ...                         ...       ...            ...
# 323488         503             Wild Rice Blend        68             10
# 323489         503             Wild Rice Blend        68             10
# 323490         503             Wild Rice Blend        68             10
# 323491         503             Wild Rice Blend        68             10
# 323492         503             Wild Rice Blend        68             10
#
#         prices  order_id  user_id  order_number  orders_day_of_week  \
# 0          5.8   3139998      138            28                   6
# 1          5.8   1977647      138            30                   6
# 2          5.8    389851      709             2                   0
# 3          5.8    652770      764             1                   3
# 4          5.8   1813452      764             3                   4
# ...        ...       ...      ...           ...                 ...
# 323488    10.8   3320117    14236             3                   1
# 323489    10.8   1365415    18847            14                   0
# 323490    10.8   1679007    22364             8                   5
# 323491    10.8   3356324    22858             6                   0
# 323492    10.8   1785866    23085             1                   6
#
#         order_hour_of_day  days_since_prior_order  first_order  \
# 0                      11                     3.0        False
# 1                      17                    20.0        False
# 2                      21                     6.0        False
# 3                      13                     NaN         True
# 4                      17                     9.0        False
# ...                   ...                     ...          ...
# 323488                 14                    21.0        False
# 323489                 15                    23.0        False
# 323490                 15                     3.0        False
# 323491                 10                     5.0        False
# 323492                 11                     NaN         True
#
#         add_to_cart_order  reordered _merge    price_range_loc  \
# 0                       5          0   both  Mid-range product
# 1                       1          1   both  Mid-range product
# 2                      20          0   both  Mid-range product
# 3                      10          0   both  Mid-range product
# 4                      11          1   both  Mid-range product
# ...                   ...        ...    ...                ...
# 323488                  6          1   both  Mid-range product
# 323489                  9          0   both  Mid-range product
# 323490                  9          0   both  Mid-range product
# 323491                  7          0   both  Mid-range product
# 323492                  8          0   both  Mid-range product
#
#            busiest_day busiest_period_of_day
# 0       Regularly busy           Most orders
# 1       Regularly busy        Average orders
# 2         Busiest days        Average orders
# 3           Least busy           Most orders
# 4           Least busy        Average orders
# ...                ...                   ...
# 323488    Busiest days           Most orders
# 323489    Busiest days           Most orders
# 323490  Regularly busy           Most orders
# 323491    Busiest days           Most orders
# 323492  Regularly busy           Most orders
#
# [210 rows x 18 columns]

# %%
# Apply the agg() function to each group to obtain the mean values for the 'order_number' column

df.agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.577493
# 2                17.320781
# 3                16.084944
# 4                17.530458
# 5                14.763075
# 6                16.658449
# 7                17.031590
# 8                15.076662
# 9                15.447580
# 10               18.681852
# 11               15.447411
# 12               14.327957
# 13               16.548642
# 14               16.960241
# 15               16.121948
# 16               17.803851
# 17               15.593633
# 18               19.674252
# 19               16.899756
# 20               16.255442
# 21               25.535479

# %%
df['order_number'].mean()
# Out:
# department_id
# 1     15.577493
# 2     17.320781
# 3     16.084944
# 4     17.530458
# 5     14.763075
# 6     16.658449
# 7     17.031590
# 8     15.076662
# 9     15.447580
# 10    18.681852
# 11    15.447411
# 12    14.327957
# 13    16.548642
# 14    16.960241
# 15    16.121948
# 16    17.803851
# 17    15.593633
# 18    19.674252
# 19    16.899756
# 20    16.255442
# 21    25.535479
# Name: order_number, dtype: float64

# %%
df.order_number.mean()
# Out:
# department_id
# 1     15.577493
# 2     17.320781
# 3     16.084944
# 4     17.530458
# 5     14.763075
# 6     16.658449
# 7     17.031590
# 8     15.076662
# 9     15.447580
# 10    18.681852
# 11    15.447411
# 12    14.327957
# 13    16.548642
# 14    16.960241
# 15    16.121948
# 16    17.803851
# 17    15.593633
# 18    19.674252
# 19    16.899756
# 20    16.255442
# 21    25.535479
# Name: order_number, dtype: float64

# %%
# Produce multiple statistics at the same time

df.agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                15.577493   1  99
# 2                17.320781   1  96
# 3                16.084944   1  99
# 4                17.530458   1  99
# 5                14.763075   1  99
# 6                16.658449   1  99
# 7                17.031590   1  99
# 8                15.076662   1  98
# 9                15.447580   1  99
# 10               18.681852   1  99
# 11               15.447411   1  99
# 12               14.327957   1  99
# 13               16.548642   1  99
# 14               16.960241   1  99
# 15               16.121948   1  99
# 16               17.803851   1  99
# 17               15.593633   1  99
# 18               19.674252   1  99
# 19               16.899756   1  99
# 20               16.255442   1  99
# 21               25.535479   1  98

# %% [markdown]
# ### 5. Create a column to generate the maximum orders for each user

# %%
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform('max')

# %%
# Check the output

ords_prods_merge.head(15) # Data doesn´t seem to be grouped by the 'user_id' column
# Out:
#     product_id                product_name  aisle_id  department_id  prices  \
# 0            1  Chocolate Sandwich Cookies        61             19     5.8
# 1            1  Chocolate Sandwich Cookies        61             19     5.8
# 2            1  Chocolate Sandwich Cookies        61             19     5.8
# 3            1  Chocolate Sandwich Cookies        61             19     5.8
# 4            1  Chocolate Sandwich Cookies        61             19     5.8
# 5            1  Chocolate Sandwich Cookies        61             19     5.8
# 6            1  Chocolate Sandwich Cookies        61             19     5.8
# 7            1  Chocolate Sandwich Cookies        61             19     5.8
# 8            1  Chocolate Sandwich Cookies        61             19     5.8
# 9            1  Chocolate Sandwich Cookies        61             19     5.8
# 10           1  Chocolate Sandwich Cookies        61             19     5.8
# 11           1  Chocolate Sandwich Cookies        61             19     5.8
# 12           1  Chocolate Sandwich Cookies        61             19     5.8
# 13           1  Chocolate Sandwich Cookies        61             19     5.8
# 14           1  Chocolate Sandwich Cookies        61             19     5.8
#
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    3139998      138            28                   6                 11
# 1    1977647      138            30                   6                 17
# 2     389851      709             2                   0                 21
# 3     652770      764             1                   3                 13
# 4    1813452      764             3                   4                 17
# 5    1701441      777            16                   1                  7
# 6    1871483      825             3                   2                 14
# 7    1290456      910            12                   3                 10
# 8     369558     1052            10                   1                 20
# 9     589712     1052            15                   1                 12
# 10   1798115     1379             1                   5                 11
# 11    497193     1480            36                   3                 13
# 12   1727826     1480            38                   4                 13
# 13   2694698     1480            39                   2                 12
# 14   3171753     1494             6                   3                 10
#
#     days_since_prior_order  first_order  add_to_cart_order  reordered _merge  \
# 0                      3.0        False                  5          0   both
# 1                     20.0        False                  1          1   both
# 2                      6.0        False                 20          0   both
# 3                      NaN         True                 10          0   both
# 4                      9.0        False                 11          1   both
# 5                     26.0        False                  7          0   both
# 6                     30.0        False                  2          0   both
# 7                     30.0        False                  1          0   both
# 8                     19.0        False                  1          0   both
# 9                     15.0        False                  2          1   both
# 10                     NaN         True                  1          0   both
# 11                     7.0        False                  1          0   both
# 12                     7.0        False                  3          1   both
# 13                    12.0        False                  4          1   both
# 14                     2.0        False                  8          0   both
#
#       price_range_loc     busiest_day busiest_period_of_day  max_order
# 0   Mid-range product  Regularly busy           Most orders         32
# 1   Mid-range product  Regularly busy        Average orders         32
# 2   Mid-range product    Busiest days        Average orders          5
# 3   Mid-range product      Least busy           Most orders          3
# 4   Mid-range product      Least busy        Average orders          3
# 5   Mid-range product    Busiest days        Average orders         26
# 6   Mid-range product  Regularly busy           Most orders          9
# 7   Mid-range product      Least busy           Most orders         12
# 8   Mid-range product    Busiest days        Average orders         20
# 9   Mid-range product    Busiest days           Most orders         20
# 10  Mid-range product  Regularly busy           Most orders         10
# 11  Mid-range product      Least busy           Most orders         43
# 12  Mid-range product      Least busy           Most orders         43
# 13  Mid-range product  Regularly busy           Most orders         43
# 14  Mid-range product      Least busy           Most orders         13

# %%
ords_prods_merge[['order_id', 'user_id', 'order_number', 'max_order']][ords_prods_merge['user_id']==1]
# Out:
#           order_id  user_id  order_number  max_order
# 92368      2539329        1             1         10
# 92369      2398795        1             2         10
# 92370       473747        1             3         10
# 92371      2254736        1             4         10
# 92372       431534        1             5         10
# 92373      3367565        1             6         10
# 92374       550135        1             7         10
# 92375      3108588        1             8         10
# 92376      2295261        1             9         10
# 92377      2550362        1            10         10
# 5971715    2398795        1             2         10
# 5971716     473747        1             3         10
# 5971717    2254736        1             4         10
# 5971718     431534        1             5         10
# 5971719    3367565        1             6         10
# 5971720     550135        1             7         10
# 5971721    3108588        1             8         10
# 5971722    2295261        1             9         10
# 5971723    2550362        1            10         10
# 6002731     431534        1             5         10
# 7157228    2539329        1             1         10
# 7157229    2398795        1             2         10
# 7157230     473747        1             3         10
# 7157231    2254736        1             4         10
# 7157232     431534        1             5         10
# 7157233    3367565        1             6         10
# 7157234     550135        1             7         10
# 7157235    3108588        1             8         10
# 7157236    2295261        1             9         10
# 7157237    2550362        1            10         10
# 7453170    2398795        1             2         10
# 7453171     550135        1             7         10
# 7453172    2550362        1            10         10
# 7518961    2398795        1             2         10
# 7518962     431534        1             5         10
# 8435031    2539329        1             1         10
# 10076906    431534        1             5         10
# 16105125    473747        1             3         10
# 16105126   2254736        1             4         10
# 16105127    431534        1             5         10
# 16105128   3367565        1             6         10
# 16105129    550135        1             7         10
# 16105130   3108588        1             8         10
# 16105131   2295261        1             9         10
# 16105132   2550362        1            10         10
# 16642084   2539329        1             1         10
# 16642085   2398795        1             2         10
# 17009387   2539329        1             1         10
# 17009388   2254736        1             4         10
# 19830897    473747        1             3         10
# 23228084   2550362        1            10         10
# 24921879   2550362        1            10         10
# 25453150   2550362        1            10         10
# 26746105    431534        1             5         10
# 29712647   3108588        1             8         10
# 29712648   2295261        1             9         10
# 29712649   2550362        1            10         10
# 32034006   3108588        1             8         10
# 32034007   2295261        1             9         10

# %%
ords_prods_merge[['order_id', 'user_id', 'order_number', 'max_order']][ords_prods_merge['user_id']==15]
# Out:
#           order_id  user_id  order_number  max_order
# 92378      2968173       15            15         22
# 92379      1870022       15            17         22
# 92380      1911383       15            18         22
# 92381      2715276       15            21         22
# 92382       487368       15            22         22
# ...            ...      ...           ...        ...
# 27546087   3135826       15             2         22
# 28007052   2570697       15            10         22
# 31447948   2685110       15             7         22
# 31447949   2883598       15            12         22
# 31447950   2715276       15            21         22
#
# [72 rows x 4 columns]

# %% [markdown]
# ### 6. Create a loyalty flag using loc

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
ords_prods_merge.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   3139998      138            28                   6                 11
# 1   1977647      138            30                   6                 17
# 2    389851      709             2                   0                 21
# 3    652770      764             1                   3                 13
# 4   1813452      764             3                   4                 17
#
#    days_since_prior_order  first_order  add_to_cart_order  reordered _merge  \
# 0                     3.0        False                  5          0   both
# 1                    20.0        False                  1          1   both
# 2                     6.0        False                 20          0   both
# 3                     NaN         True                 10          0   both
# 4                     9.0        False                 11          1   both
#
#      price_range_loc     busiest_day busiest_period_of_day  max_order  \
# 0  Mid-range product  Regularly busy           Most orders         32
# 1  Mid-range product  Regularly busy        Average orders         32
# 2  Mid-range product    Busiest days        Average orders          5
# 3  Mid-range product      Least busy           Most orders          3
# 4  Mid-range product      Least busy        Average orders          3
#
#        loyalty_flag
# 0  Regular customer
# 1  Regular customer
# 2      New customer
# 3      New customer
# 4      New customer

# %% [markdown]
# ### 7. Find the aggregated mean of the 'order_number' column grouped by 'department_id'

# %%
ords_prods_merge.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     15.457838
# 2     17.277920
# 3     17.170395
# 4     17.811403
# 5     15.215751
# 6     16.439806
# 7     17.225802
# 8     15.340650
# 9     15.895474
# 10    20.197148
# 11    16.170638
# 12    15.887671
# 13    16.583536
# 14    16.773669
# 15    16.165037
# 16    17.665606
# 17    15.694469
# 18    19.310397
# 19    17.177343
# 20    16.473447
# 21    22.902379
# Name: order_number, dtype: float64

# %%
df['order_number'].mean()
# Out:
# department_id
# 1     15.577493
# 2     17.320781
# 3     16.084944
# 4     17.530458
# 5     14.763075
# 6     16.658449
# 7     17.031590
# 8     15.076662
# 9     15.447580
# 10    18.681852
# 11    15.447411
# 12    14.327957
# 13    16.548642
# 14    16.960241
# 15    16.121948
# 16    17.803851
# 17    15.593633
# 18    19.674252
# 19    16.899756
# 20    16.255442
# 21    25.535479
# Name: order_number, dtype: float64

# %% [markdown]
# #### Overall the aggregated mean values seem to be slightly higher for each department when looking at the entire data frame.

# %% [markdown]
# ### 8.  Look at spending habits of loyalty groups

# %% [markdown]
# #### Question 5

# %% [markdown]
# The marketing team at Instacart wants to know whether there’s a difference between the spending habits of the three types of customers you identified. Use the loyalty flag you created and check the basic statistics of the product prices for each loyalty category (Loyal Customer, Regular Customer, and New Customer). What you’re trying to determine is whether the prices of products purchased by loyal customers differ from those purchased by regular or new customers.

# %%
ords_prods_merge.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.386336  1.0  99999.0
# New customer      13.294670  1.0  99999.0
# Regular customer  12.495717  1.0  99999.0

# %% [markdown]
# #### The average price of a product purchased by a new customer is about 3 US dollars more than that of a loyal customer.

# %% [markdown]
# #### Question 6

# %% [markdown]
# The team now wants to target different types of spenders in their marketing campaigns. This can be achieved by looking at the prices of the items people are buying. Create a spending flag for each user based on the average price across all their orders using the following criteria: if the mean of the prices of products purchased by a user is lower than 10, then flag them as a “Low spender.” If the mean of the prices of products purchased by a user is higher than or equal to 10, then flag them as a “High spender.”

# %%
# Use transform() to determine the average price across all products purchased by each user

ords_prods_merge['average_product_price'] = ords_prods_merge.groupby(['user_id'])['prices'].transform('mean')

# %%
# View relevant columns

ords_prods_merge[['user_id', 'average_product_price']].head(15) # Again the data isn´t grouped by 'user_id'
# Out:
#     user_id  average_product_price
# 0       138               6.935811
# 1       138               6.935811
# 2       709               7.930208
# 3       764               4.972414
# 4       764               4.972414
# 5       777               6.935398
# 6       825               5.957576
# 7       910               6.680000
# 8      1052               7.162500
# 9      1052               7.162500
# 10     1379               5.813636
# 11     1480               5.081633
# 12     1480               5.081633
# 13     1480               5.081633
# 14     1494               6.803797

# %%
# Create spending_flag column with given criteria using loc() function

ords_prods_merge.loc[ords_prods_merge['average_product_price'] >= 10, 'spending_flag'] = 'High spender'

# %%
ords_prods_merge.loc[ords_prods_merge['average_product_price'] < 10, 'spending_flag'] = 'Low spender'

# %%
# Check frequency of new spending_flag column

ords_prods_merge['spending_flag'].value_counts(dropna = False)
# Out:
# spending_flag
# Low spender     31770614
# High spender      634245
# Name: count, dtype: int64

# %%
# View relevant columns of updated dataframe

ords_prods_merge[['user_id', 'average_product_price', 'spending_flag']][ords_prods_merge['user_id']==1]
# Out:
#           user_id  average_product_price spending_flag
# 92368           1               6.367797   Low spender
# 92369           1               6.367797   Low spender
# 92370           1               6.367797   Low spender
# 92371           1               6.367797   Low spender
# 92372           1               6.367797   Low spender
# 92373           1               6.367797   Low spender
# 92374           1               6.367797   Low spender
# 92375           1               6.367797   Low spender
# 92376           1               6.367797   Low spender
# 92377           1               6.367797   Low spender
# 5971715         1               6.367797   Low spender
# 5971716         1               6.367797   Low spender
# 5971717         1               6.367797   Low spender
# 5971718         1               6.367797   Low spender
# 5971719         1               6.367797   Low spender
# 5971720         1               6.367797   Low spender
# 5971721         1               6.367797   Low spender
# 5971722         1               6.367797   Low spender
# 5971723         1               6.367797   Low spender
# 6002731         1               6.367797   Low spender
# 7157228         1               6.367797   Low spender
# 7157229         1               6.367797   Low spender
# 7157230         1               6.367797   Low spender
# 7157231         1               6.367797   Low spender
# 7157232         1               6.367797   Low spender
# 7157233         1               6.367797   Low spender
# 7157234         1               6.367797   Low spender
# 7157235         1               6.367797   Low spender
# 7157236         1               6.367797   Low spender
# 7157237         1               6.367797   Low spender
# 7453170         1               6.367797   Low spender
# 7453171         1               6.367797   Low spender
# 7453172         1               6.367797   Low spender
# 7518961         1               6.367797   Low spender
# 7518962         1               6.367797   Low spender
# 8435031         1               6.367797   Low spender
# 10076906        1               6.367797   Low spender
# 16105125        1               6.367797   Low spender
# 16105126        1               6.367797   Low spender
# 16105127        1               6.367797   Low spender
# 16105128        1               6.367797   Low spender
# 16105129        1               6.367797   Low spender
# 16105130        1               6.367797   Low spender
# 16105131        1               6.367797   Low spender
# 16105132        1               6.367797   Low spender
# 16642084        1               6.367797   Low spender
# 16642085        1               6.367797   Low spender
# 17009387        1               6.367797   Low spender
# 17009388        1               6.367797   Low spender
# 19830897        1               6.367797   Low spender
# 23228084        1               6.367797   Low spender
# 24921879        1               6.367797   Low spender
# 25453150        1               6.367797   Low spender
# 26746105        1               6.367797   Low spender
# 29712647        1               6.367797   Low spender
# 29712648        1               6.367797   Low spender
# 29712649        1               6.367797   Low spender
# 32034006        1               6.367797   Low spender
# 32034007        1               6.367797   Low spender

# %% [markdown]
# ### 9. Determine order frequency of each user

# %% [markdown]
# #### Question 7

# %% [markdown]
# In order to send relevant notifications to users within the app (for instance, asking users if they want to buy the same item again), the Instacart team wants you to determine frequent versus non-frequent customers. Create an order frequency flag that marks the regularity of a user’s ordering behavior according to the median in the “days_since_prior_order” column. The criteria for the flag should be as follows:
# If the median of “days_since_prior_order” is higher than 20, then the customer should be labeled a “Non-frequent customer.”
# If the median is higher than 10 and lower than or equal to 20, then the customer should be labeled a “Regular customer.”
# If the median is lower than or equal to 10, then the customer should be labeled a “Frequent customer.”

# %%
# Use transform() to determine the median number of days between orders for each user

ords_prods_merge['median_days_between_orders'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform('median')

# %%
# View relevant columns

ords_prods_merge[['user_id', 'median_days_between_orders']][ords_prods_merge['user_id']==1]
# Out:
#           user_id  median_days_between_orders
# 92368           1                        20.5
# 92369           1                        20.5
# 92370           1                        20.5
# 92371           1                        20.5
# 92372           1                        20.5
# 92373           1                        20.5
# 92374           1                        20.5
# 92375           1                        20.5
# 92376           1                        20.5
# 92377           1                        20.5
# 5971715         1                        20.5
# 5971716         1                        20.5
# 5971717         1                        20.5
# 5971718         1                        20.5
# 5971719         1                        20.5
# 5971720         1                        20.5
# 5971721         1                        20.5
# 5971722         1                        20.5
# 5971723         1                        20.5
# 6002731         1                        20.5
# 7157228         1                        20.5
# 7157229         1                        20.5
# 7157230         1                        20.5
# 7157231         1                        20.5
# 7157232         1                        20.5
# 7157233         1                        20.5
# 7157234         1                        20.5
# 7157235         1                        20.5
# 7157236         1                        20.5
# 7157237         1                        20.5
# 7453170         1                        20.5
# 7453171         1                        20.5
# 7453172         1                        20.5
# 7518961         1                        20.5
# 7518962         1                        20.5
# 8435031         1                        20.5
# 10076906        1                        20.5
# 16105125        1                        20.5
# 16105126        1                        20.5
# 16105127        1                        20.5
# 16105128        1                        20.5
# 16105129        1                        20.5
# 16105130        1                        20.5
# 16105131        1                        20.5
# 16105132        1                        20.5
# 16642084        1                        20.5
# 16642085        1                        20.5
# 17009387        1                        20.5
# 17009388        1                        20.5
# 19830897        1                        20.5
# 23228084        1                        20.5
# 24921879        1                        20.5
# 25453150        1                        20.5
# 26746105        1                        20.5
# 29712647        1                        20.5
# 29712648        1                        20.5
# 29712649        1                        20.5
# 32034006        1                        20.5
# 32034007        1                        20.5

# %%
# Create frequency_flag column based on given criteria using loc() function

ords_prods_merge.loc[ords_prods_merge['median_days_between_orders'] > 20, 'frequency_flag'] = 'Non-frequent customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['median_days_between_orders'] <= 20) & (ords_prods_merge['median_days_between_orders'] > 10) , 'frequency_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['median_days_between_orders'] <= 10, 'frequency_flag'] = 'Frequent customer'

# %%
# Check frequency of new frequency_flag column

ords_prods_merge['frequency_flag'].value_counts(dropna = False)
# Out:
# frequency_flag
# Frequent customer        21559853
# Regular customer          7208564
# Non-frequent customer     3636437
# nan                             5
# Name: count, dtype: int64

# %%
# Check nan values

ords_prods_merge[['user_id', 'days_since_prior_order', 'median_days_between_orders', 'frequency_flag']][ords_prods_merge['frequency_flag']=='nan']
# Out:
#           user_id  days_since_prior_order  median_days_between_orders  \
# 6234909    159838                     NaN                         NaN
# 12947653   159838                     NaN                         NaN
# 13839012   159838                     NaN                         NaN
# 14758536   159838                     NaN                         NaN
# 21673807   159838                     NaN                         NaN
#
#          frequency_flag
# 6234909             nan
# 12947653            nan
# 13839012            nan
# 14758536            nan
# 21673807            nan

# %% [markdown]
# #### A possible explanation for these 'nan' values is that customer 159838 has only made one order on the platform.

# %%
# View relevant columns of updated dataframe

ords_prods_merge[['user_id', 'days_since_prior_order', 'median_days_between_orders', 'frequency_flag']][ords_prods_merge['user_id']==1]
# Out:
#           user_id  days_since_prior_order  median_days_between_orders  \
# 92368           1                     NaN                        20.5
# 92369           1                    15.0                        20.5
# 92370           1                    21.0                        20.5
# 92371           1                    29.0                        20.5
# 92372           1                    28.0                        20.5
# 92373           1                    19.0                        20.5
# 92374           1                    20.0                        20.5
# 92375           1                    14.0                        20.5
# 92376           1                     0.0                        20.5
# 92377           1                    30.0                        20.5
# 5971715         1                    15.0                        20.5
# 5971716         1                    21.0                        20.5
# 5971717         1                    29.0                        20.5
# 5971718         1                    28.0                        20.5
# 5971719         1                    19.0                        20.5
# 5971720         1                    20.0                        20.5
# 5971721         1                    14.0                        20.5
# 5971722         1                     0.0                        20.5
# 5971723         1                    30.0                        20.5
# 6002731         1                    28.0                        20.5
# 7157228         1                     NaN                        20.5
# 7157229         1                    15.0                        20.5
# 7157230         1                    21.0                        20.5
# 7157231         1                    29.0                        20.5
# 7157232         1                    28.0                        20.5
# 7157233         1                    19.0                        20.5
# 7157234         1                    20.0                        20.5
# 7157235         1                    14.0                        20.5
# 7157236         1                     0.0                        20.5
# 7157237         1                    30.0                        20.5
# 7453170         1                    15.0                        20.5
# 7453171         1                    20.0                        20.5
# 7453172         1                    30.0                        20.5
# 7518961         1                    15.0                        20.5
# 7518962         1                    28.0                        20.5
# 8435031         1                     NaN                        20.5
# 10076906        1                    28.0                        20.5
# 16105125        1                    21.0                        20.5
# 16105126        1                    29.0                        20.5
# 16105127        1                    28.0                        20.5
# 16105128        1                    19.0                        20.5
# 16105129        1                    20.0                        20.5
# 16105130        1                    14.0                        20.5
# 16105131        1                     0.0                        20.5
# 16105132        1                    30.0                        20.5
# 16642084        1                     NaN                        20.5
# 16642085        1                    15.0                        20.5
# 17009387        1                     NaN                        20.5
# 17009388        1                    29.0                        20.5
# 19830897        1                    21.0                        20.5
# 23228084        1                    30.0                        20.5
# 24921879        1                    30.0                        20.5
# 25453150        1                    30.0                        20.5
# 26746105        1                    28.0                        20.5
# 29712647        1                    14.0                        20.5
# 29712648        1                     0.0                        20.5
# 29712649        1                    30.0                        20.5
# 32034006        1                    14.0                        20.5
# 32034007        1                     0.0                        20.5
#
#                  frequency_flag
# 92368     Non-frequent customer
# 92369     Non-frequent customer
# 92370     Non-frequent customer
# 92371     Non-frequent customer
# 92372     Non-frequent customer
# 92373     Non-frequent customer
# 92374     Non-frequent customer
# 92375     Non-frequent customer
# 92376     Non-frequent customer
# 92377     Non-frequent customer
# 5971715   Non-frequent customer
# 5971716   Non-frequent customer
# 5971717   Non-frequent customer
# 5971718   Non-frequent customer
# 5971719   Non-frequent customer
# 5971720   Non-frequent customer
# 5971721   Non-frequent customer
# 5971722   Non-frequent customer
# 5971723   Non-frequent customer
# 6002731   Non-frequent customer
# 7157228   Non-frequent customer
# 7157229   Non-frequent customer
# 7157230   Non-frequent customer
# 7157231   Non-frequent customer
# 7157232   Non-frequent customer
# 7157233   Non-frequent customer
# 7157234   Non-frequent customer
# 7157235   Non-frequent customer
# 7157236   Non-frequent customer
# 7157237   Non-frequent customer
# 7453170   Non-frequent customer
# 7453171   Non-frequent customer
# 7453172   Non-frequent customer
# 7518961   Non-frequent customer
# 7518962   Non-frequent customer
# 8435031   Non-frequent customer
# 10076906  Non-frequent customer
# 16105125  Non-frequent customer
# 16105126  Non-frequent customer
# 16105127  Non-frequent customer
# 16105128  Non-frequent customer
# 16105129  Non-frequent customer
# 16105130  Non-frequent customer
# 16105131  Non-frequent customer
# 16105132  Non-frequent customer
# 16642084  Non-frequent customer
# 16642085  Non-frequent customer
# 17009387  Non-frequent customer
# 17009388  Non-frequent customer
# 19830897  Non-frequent customer
# 23228084  Non-frequent customer
# 24921879  Non-frequent customer
# 25453150  Non-frequent customer
# 26746105  Non-frequent customer
# 29712647  Non-frequent customer
# 29712648  Non-frequent customer
# 29712649  Non-frequent customer
# 32034006  Non-frequent customer
# 32034007  Non-frequent customer

# %%
# Check entire dataframe

ords_prods_merge.head(15)
# Out:
#     product_id                product_name  aisle_id  department_id  prices  \
# 0            1  Chocolate Sandwich Cookies        61             19     5.8
# 1            1  Chocolate Sandwich Cookies        61             19     5.8
# 2            1  Chocolate Sandwich Cookies        61             19     5.8
# 3            1  Chocolate Sandwich Cookies        61             19     5.8
# 4            1  Chocolate Sandwich Cookies        61             19     5.8
# 5            1  Chocolate Sandwich Cookies        61             19     5.8
# 6            1  Chocolate Sandwich Cookies        61             19     5.8
# 7            1  Chocolate Sandwich Cookies        61             19     5.8
# 8            1  Chocolate Sandwich Cookies        61             19     5.8
# 9            1  Chocolate Sandwich Cookies        61             19     5.8
# 10           1  Chocolate Sandwich Cookies        61             19     5.8
# 11           1  Chocolate Sandwich Cookies        61             19     5.8
# 12           1  Chocolate Sandwich Cookies        61             19     5.8
# 13           1  Chocolate Sandwich Cookies        61             19     5.8
# 14           1  Chocolate Sandwich Cookies        61             19     5.8
#
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    3139998      138            28                   6                 11
# 1    1977647      138            30                   6                 17
# 2     389851      709             2                   0                 21
# 3     652770      764             1                   3                 13
# 4    1813452      764             3                   4                 17
# 5    1701441      777            16                   1                  7
# 6    1871483      825             3                   2                 14
# 7    1290456      910            12                   3                 10
# 8     369558     1052            10                   1                 20
# 9     589712     1052            15                   1                 12
# 10   1798115     1379             1                   5                 11
# 11    497193     1480            36                   3                 13
# 12   1727826     1480            38                   4                 13
# 13   2694698     1480            39                   2                 12
# 14   3171753     1494             6                   3                 10
#
#     ...  _merge    price_range_loc     busiest_day  busiest_period_of_day  \
# 0   ...    both  Mid-range product  Regularly busy            Most orders
# 1   ...    both  Mid-range product  Regularly busy         Average orders
# 2   ...    both  Mid-range product    Busiest days         Average orders
# 3   ...    both  Mid-range product      Least busy            Most orders
# 4   ...    both  Mid-range product      Least busy         Average orders
# 5   ...    both  Mid-range product    Busiest days         Average orders
# 6   ...    both  Mid-range product  Regularly busy            Most orders
# 7   ...    both  Mid-range product      Least busy            Most orders
# 8   ...    both  Mid-range product    Busiest days         Average orders
# 9   ...    both  Mid-range product    Busiest days            Most orders
# 10  ...    both  Mid-range product  Regularly busy            Most orders
# 11  ...    both  Mid-range product      Least busy            Most orders
# 12  ...    both  Mid-range product      Least busy            Most orders
# 13  ...    both  Mid-range product  Regularly busy            Most orders
# 14  ...    both  Mid-range product      Least busy            Most orders
#
#    max_order      loyalty_flag average_product_price spending_flag  \
# 0         32  Regular customer              6.935811   Low spender
# 1         32  Regular customer              6.935811   Low spender
# 2          5      New customer              7.930208   Low spender
# 3          3      New customer              4.972414   Low spender
# 4          3      New customer              4.972414   Low spender
# 5         26  Regular customer              6.935398   Low spender
# 6          9      New customer              5.957576   Low spender
# 7         12  Regular customer              6.680000   Low spender
# 8         20  Regular customer              7.162500   Low spender
# 9         20  Regular customer              7.162500   Low spender
# 10        10      New customer              5.813636   Low spender
# 11        43    Loyal customer              5.081633   Low spender
# 12        43    Loyal customer              5.081633   Low spender
# 13        43    Loyal customer              5.081633   Low spender
# 14        13  Regular customer              6.803797   Low spender
#
#     median_days_between_orders     frequency_flag
# 0                          8.0  Frequent customer
# 1                          8.0  Frequent customer
# 2                          8.0  Frequent customer
# 3                          9.0  Frequent customer
# 4                          9.0  Frequent customer
# 5                         11.0   Regular customer
# 6                         20.0   Regular customer
# 7                          6.0  Frequent customer
# 8                         10.0  Frequent customer
# 9                         10.0  Frequent customer
# 10                        20.0   Regular customer
# 11                         7.0  Frequent customer
# 12                         7.0  Frequent customer
# 13                         7.0  Frequent customer
# 14                         7.0  Frequent customer
#
# [15 rows x 24 columns]

# %% [markdown]
# ### 10. Quality check for the 'prices' column

# %%
# Check the column statistics
ords_prods_merge['prices'].describe()
# Out:
# count    3.240486e+07
# mean     1.198023e+01
# std      4.956554e+02
# min      1.000000e+00
# 25%      4.200000e+00
# 50%      7.400000e+00
# 75%      1.130000e+01
# max      9.999900e+04
# Name: prices, dtype: float64

# %%
ords_prods_merge['prices'].mean()
# Out:
# 11.980225638383468

# %%
ords_prods_merge['prices'].median()
# Out:
# 7.4

# %%
ords_prods_merge['prices'].max()
# Out:
# 99999.0

# %%
# Look for outliers

ords_prods_merge.loc[ords_prods_merge['prices'] > 100]
# Out:
#           product_id                      product_name  aisle_id  \
# 13100147       21553  Lowfat 2% Milkfat Cottage Cheese       108
# 13100148       21553  Lowfat 2% Milkfat Cottage Cheese       108
# 13100149       21553  Lowfat 2% Milkfat Cottage Cheese       108
# 13100150       21553  Lowfat 2% Milkfat Cottage Cheese       108
# 13100151       21553  Lowfat 2% Milkfat Cottage Cheese       108
# ...              ...                               ...       ...
# 21786876       33664             2 % Reduced Fat  Milk        84
# 21786877       33664             2 % Reduced Fat  Milk        84
# 21786878       33664             2 % Reduced Fat  Milk        84
# 21786879       33664             2 % Reduced Fat  Milk        84
# 21786880       33664             2 % Reduced Fat  Milk        84
#
#           department_id   prices  order_id  user_id  order_number  \
# 13100147             16  14900.0    912404       17            12
# 13100148             16  14900.0    603376       17            22
# 13100149             16  14900.0   3264360      135             2
# 13100150             16  14900.0    892534      135             3
# 13100151             16  14900.0    229704      342             8
# ...                 ...      ...       ...      ...           ...
# 21786876             16  99999.0   2249946   204099            29
# 21786877             16  99999.0   2363282   204099            31
# 21786878             16  99999.0   3181945   204395            13
# 21786879             16  99999.0   2486215   205227             7
# 21786880             16  99999.0   2232716   205227            10
#
#           orders_day_of_week  order_hour_of_day  ...  _merge  \
# 13100147                   2                 14  ...    both
# 13100148                   6                 16  ...    both
# 13100149                   2                 21  ...    both
# 13100150                   0                  8  ...    both
# 13100151                   1                 19  ...    both
# ...                      ...                ...  ...     ...
# 21786876                   0                  8  ...    both
# 21786877                   0                  9  ...    both
# 21786878                   3                 15  ...    both
# 21786879                   3                 20  ...    both
# 21786880                   0                 11  ...    both
#
#              price_range_loc     busiest_day  busiest_period_of_day max_order  \
# 13100147  High-range product  Regularly busy            Most orders        40
# 13100148  High-range product  Regularly busy         Average orders        40
# 13100149  High-range product  Regularly busy         Average orders         4
# 13100150  High-range product    Busiest days            Most orders         4
# 13100151  High-range product    Busiest days         Average orders        16
# ...                      ...             ...                    ...       ...
# 21786876  High-range product    Busiest days            Most orders        39
# 21786877  High-range product    Busiest days            Most orders        39
# 21786878  High-range product      Least busy            Most orders        15
# 21786879  High-range product      Least busy         Average orders        12
# 21786880  High-range product    Busiest days            Most orders        12
#
#               loyalty_flag average_product_price spending_flag  \
# 13100147  Regular customer            108.648299  High spender
# 13100148  Regular customer            108.648299  High spender
# 13100149      New customer           1154.792308  High spender
# 13100150      New customer           1154.792308  High spender
# 13100151  Regular customer            114.426619  High spender
# ...                    ...                   ...           ...
# 21786876  Regular customer           1106.743956  High spender
# 21786877  Regular customer           1106.743956  High spender
# 21786878  Regular customer            451.153540  High spender
# 21786879  Regular customer           1178.381871  High spender
# 21786880  Regular customer           1178.381871  High spender
#
#           median_days_between_orders         frequency_flag
# 13100147                         5.0      Frequent customer
# 13100148                         5.0      Frequent customer
# 13100149                        12.0       Regular customer
# 13100150                        12.0       Regular customer
# 13100151                        23.0  Non-frequent customer
# ...                              ...                    ...
# 21786876                         4.0      Frequent customer
# 21786877                         4.0      Frequent customer
# 21786878                         5.0      Frequent customer
# 21786879                        12.0       Regular customer
# 21786880                        12.0       Regular customer
#
# [5127 rows x 24 columns]

# %%
# Transform the outliers into missing values

ords_prods_merge.loc[ords_prods_merge['prices'] > 100, 'prices'] = np.nan

# %%
# Check the output

ords_prods_merge['prices'].max()
# Out:
# 25.0

# %% [markdown]
# ### 11. Export updated dataframe

# %%
# Export derived data frame as pickle file
ords_prods_merge.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_grouped.pkl'))
